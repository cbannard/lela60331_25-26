# %%
import gensim.downloader as api
w = api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
U1="We suppose a very long train travelling along the rails with the constant velocity and in the direction indicated in Figure 1"
U2="People travelling in this train will with advantage use the train as a rigid reference-body"
U3="they regard all events in reference to the train"
U4="Then every event which takes place along the line also takes place at a particular point of the train"
U5 ="Also the definition of simultaneity can be given relative to the train in exactly the same way as with respect to the embankment"

# %%
U1=U1.lower().split()

# %%
U2=U2.lower().split()

# %%
U3=U3.lower().split()

# %%
U4=U4.lower().split()

# %%
U5=U5.lower().split()

# %%
sent1 = "cat"
sent2 = "dog"
w.similarity(sent1, sent2)
# Out:
# 0.76094574
